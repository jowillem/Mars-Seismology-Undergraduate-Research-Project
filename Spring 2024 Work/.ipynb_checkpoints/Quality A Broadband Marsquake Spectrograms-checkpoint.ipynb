# %%
import matplotlib.pyplot as plt
import numpy as np
from obspy import read
from scipy.signal import spectrogram
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

# %%
stream = read(r'C:\Users\wille\Mars-Seismology-Undergraduate-Research-Project\InSight-seismic-data-downloader\DATA\BROADBAND\A\S0235b\S0235b_DISP.mseed')

data = stream[0].data
sampling_freq = stream[0].stats.sampling_rate

# Set parameters for the spectrogram
nperseg = 256  # Number of data points in each segment
noverlap = 128  # Number of overlapping points between segments

# Create the spectrogram
frequencies, times, Sxx = spectrogram(data, fs=sampling_freq, nperseg=256*4) #nperseg samples per segment, balance between high resolution and low resolution.
times -= 60*30

# Plot the spectrogram
plt.figure(figsize=(12, 6))
plt.pcolormesh(times, frequencies, 10 * np.log10(Sxx), shading='gouraud', cmap="plasma", vmin=-200, vmax=-170)
plt.title('S0235b Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.colorbar(label='Intensity (dB)')
plt.axvline(2100)
plt.ylim(0.05, 1)  # Limit the y-axis to focus on lower frequencies
plt.xlim(0,2000)
plt.show()

stcopy = stream.copy()
stcopy.taper(0.05)
stcopy.filter("bandpass", freqmin=0.2, freqmax=0.9, corners=4)
stcopy[0].plot();

# %%
stream2 = read(r"C:\Users\wille\Mars-Seismology-Undergraduate-Research-Project\InSight-seismic-data-downloader\DATA\BROADBAND\A\S0864a\S0864a_VEL.mseed")

data2 = stream2[0].data
sampling_freq2 = stream2[0].stats.sampling_rate

# Set parameters for the spectrogram
nperseg = 256  # Number of data points in each segment
noverlap = 128  # Number of overlapping points between segments

# Create the spectrogram
frequencies2, times2, Sxx2 = spectrogram(data2, fs=sampling_freq2, nperseg=256*4) #nperseg samples per segment, balance between high resolution and low resolution.
times2 -= 60*30

# Plot the spectrogram
plt.figure(figsize=(12, 6))
plt.pcolormesh(times2, frequencies2, 10 * np.log10(Sxx2), shading='gouraud', cmap="plasma", vmin=-200, vmax=-160)
plt.title('S0864a Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.colorbar(label='Intensity (dB)')
plt.axvline(2100)
plt.ylim(0.2, 1)  # Limit the y-axis to focus on lower frequencies
plt.xlim(0,600)
plt.show()

stcopy2 = stream2.copy()
stcopy2.taper(0.05)
stcopy2.filter("bandpass", freqmin=0.1, freqmax=0.8, corners=4, zerophase=False)
stcopy2[0].plot();

trz = stcopy2.select(channel="BHZ")[0]
origin_time = 60*30
p_predicted = 226.497
s_predicted = 403.212
time_for_trz = trz.times() - origin_time

plt.figure(figsize=(6, 4))
plt.plot(time_for_trz, trz.data)
plt.xlim(0,600)
plt.ylim(-5e-9,5e-9);

# %%
stream3 = read(r"C:\Users\wille\Mars-Seismology-Undergraduate-Research-Project\InSight-seismic-data-downloader\DATA\BROADBAND\A\S1000a\S1000a_DISP.mseed")

data3 = stream3[0].data
sampling_freq3 = stream3[0].stats.sampling_rate

# Set parameters for the spectrogram
nperseg = 256  # Number of data points in each segment
noverlap = 128  # Number of overlapping points between segments

# Create the spectrogram
frequencies3, times3, Sxx3 = spectrogram(data3, fs=sampling_freq3, nperseg=256*8) #nperseg samples per segment, balance between high resolution and low resolution.
times3 -= 60*30

# Plot the spectrogram
plt.figure(figsize=(12, 6))
plt.pcolormesh(times3, frequencies3, 10 * np.log10(Sxx3), shading='gouraud', cmap="plasma", vmin=-200, vmax=-170)
plt.title('S1000a Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.colorbar(label='Intensity (dB)')
plt.axvline(2100)
plt.ylim(0.2, 1)  # Limit the y-axis to focus on lower frequencies
plt.xlim(200,2000)
plt.show()

stcopy3 = stream3.copy()
stcopy3.taper(0.05)
stcopy3.filter("bandpass", freqmin=0.1, freqmax=0.8, corners=4, zerophase=False)
stcopy3[0].plot();

trz2 = stcopy3.select(channel="BHZ")[0]
origin_time = 60*30
time_for_trz2 = trz2.times() - origin_time

plt.figure(figsize=(6, 4))
plt.plot(time_for_trz2, trz2.data)
plt.xlim(0,2000)
plt.ylim(-5e-9,5e-9);

# %%
stream4 = read(r"C:\Users\wille\Mars-Seismology-Undergraduate-Research-Project\InSight-seismic-data-downloader\DATA\BROADBAND\A\S1015f\S1015f_VEL.mseed")

data4 = stream4[0].data
sampling_freq4 = stream4[0].stats.sampling_rate

# Set parameters for the spectrogram
nperseg = 256  # Number of data points in each segment
noverlap = 128  # Number of overlapping points between segments

# Create the spectrogram
frequencies4, times4, Sxx4 = spectrogram(data4, fs=sampling_freq4, nperseg=256, noverlap=256//2) #nperseg samples per segment, balance between high resolution and low resolution.
times4 -= 60*30
#print(times)

# Plot the spectrogram
plt.figure(figsize=(12, 6))
plt.pcolormesh(times4, frequencies4, 10 * np.log10(Sxx4), shading='gouraud', cmap="plasma", vmin=-200, vmax=-160)
plt.title('S1015f Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.colorbar(label='Intensity (dB)')
plt.axvline(2100)
plt.ylim(0.25, 1)  # Limit the y-axis to focus on lower frequencies
plt.xlim(0,500)
plt.show()

stcopy4 = stream4.copy()
stcopy4.taper(0.05)
stcopy4.filter("bandpass", freqmin=0.1, freqmax=0.8, corners=4, zerophase=False)
stcopy4[0].plot();

trz4 = stcopy4.select(channel="BHN")[0]
origin_time = 60*30
time_for_trz4 = trz4.times() - origin_time

plt.figure(figsize=(6, 4))
plt.plot(time_for_trz4, trz4.data)
plt.xlim(0,500)
plt.ylim(-3e-9,3e-9);

# %%
stream5 = read(r"C:\Users\wille\Mars-Seismology-Undergraduate-Research-Project\InSight-seismic-data-downloader\DATA\BROADBAND\A\S1094b\S1094b_DISP.mseed")

data5 = stream5[0].data
sampling_freq5 = stream5[0].stats.sampling_rate

# Set parameters for the spectrogram
nperseg = 256  # Number of data points in each segment
noverlap = 128  # Number of overlapping points between segments

# Create the spectrogram
frequencies5, times5, Sxx5 = spectrogram(data5, fs=sampling_freq5, nperseg=256*4) #nperseg samples per segment, balance between high resolution and low resolution.
times5 -= 60*30

# Plot the spectrogram
plt.figure(figsize=(12, 6))
plt.pcolormesh(times5, frequencies5, 10 * np.log10(Sxx5), shading='gouraud', cmap="plasma", vmin=-200, vmax=-160)
plt.title('S1094b Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.colorbar(label='Intensity (dB)')
plt.axvline(2100)
plt.ylim(0.2, 1)  # Limit the y-axis to focus on lower frequencies
plt.xlim(250,2000)
plt.show()

stcopy5 = stream5.copy()
stcopy5.taper(0.05)
stcopy5.filter("bandpass", freqmin=0.1, freqmax=0.8, corners=4, zerophase=False)
stcopy5[0].plot();

trz5 = stcopy5.select(channel="BHN")[0]
origin_time = 60*30
time_for_trz5 = trz5.times() - origin_time

plt.figure(figsize=(6, 4))
plt.plot(time_for_trz5, trz5.data)
plt.xlim(0,2000)
plt.ylim(-5e-9,5e-9);

# %%
stream6 = read(r"C:\Users\wille\Mars-Seismology-Undergraduate-Research-Project\InSight-seismic-data-downloader\DATA\BROADBAND\A\S1102a\S1102a_VEL.mseed")

data6 = stream6[0].data
sampling_freq6 = stream6[0].stats.sampling_rate

# Set parameters for the spectrogram
nperseg = 256  # Number of data points in each segment
noverlap = 128  # Number of overlapping points between segments

# Create the spectrogram
frequencies6, times6, Sxx6 = spectrogram(data6, fs=sampling_freq6, nperseg=256*2) #nperseg samples per segment, balance between high resolution and low resolution.
times6 -= 60*30

# Plot the spectrogram
plt.figure(figsize=(12, 6))
plt.pcolormesh(times6, frequencies6, 10 * np.log10(Sxx6), shading='gouraud', cmap="plasma", vmin=-200, vmax=-150)
plt.title('S1102a Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.colorbar(label='Intensity (dB)')
plt.axvline(2100)
plt.ylim(0.1, 1)  # Limit the y-axis to focus on lower frequencies
plt.xlim(300,1200)
plt.show()

stcopy6 = stream6.copy()
stcopy6.taper(0.05)
stcopy6.filter("bandpass", freqmin=0.1, freqmax=0.8, corners=4, zerophase=False)
stcopy6[0].plot();

trz6 = stcopy6.select(channel="BHN")[0]
origin_time = 60*30
time_for_trz6 = trz6.times() - origin_time

plt.figure(figsize=(6, 4))
plt.plot(time_for_trz6, trz6.data)
plt.xlim(0,1400)
plt.ylim(-5e-9,5e-9);

# %%
stream7 = read(r"C:\Users\wille\Mars-Seismology-Undergraduate-Research-Project\InSight-seismic-data-downloader\DATA\BROADBAND\A\S1133c\S1133c_DISP.mseed")

data7 = stream7[0].data
sampling_freq7 = stream7[0].stats.sampling_rate

# Set parameters for the spectrogram
nperseg = 256  # Number of data points in each segment
noverlap = 128  # Number of overlapping points between segments

# Create the spectrogram
frequencies7, times7, Sxx7 = spectrogram(data7, fs=sampling_freq7, nperseg=256) #nperseg samples per segment, balance between high resolution and low resolution.
times7 -= 60*30

# Plot the spectrogram
plt.figure(figsize=(12, 6))
plt.pcolormesh(times7, frequencies7, 10 * np.log10(Sxx7), shading='gouraud', cmap="plasma", vmin=-200, vmax=-160)
plt.title('S1133c Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.colorbar(label='Intensity (dB)')
plt.axvline(2100)
plt.ylim(0.1, 1)  # Limit the y-axis to focus on lower frequencies
plt.xlim(200,600)
plt.show()

stcopy7 = stream7.copy()
stcopy7.taper(0.05)
stcopy7.filter("bandpass", freqmin=0.1, freqmax=0.8, corners=4, zerophase=False)
stcopy7[0].plot();

trz7 = stcopy7.select(channel="BHN")[0]
origin_time = 60*30
time_for_trz7 = trz7.times() - origin_time

plt.figure(figsize=(6, 4))
plt.plot(time_for_trz7, trz7.data)
plt.xlim(0,600)
plt.ylim(-5e-9,5e-9);

# %%
stream8 = read(r"C:\Users\wille\Mars-Seismology-Undergraduate-Research-Project\InSight-seismic-data-downloader\DATA\BROADBAND\A\S1222a\S1222a_DISP.mseed")

data8 = stream8[0].data
sampling_freq8 = stream8[0].stats.sampling_rate

# Set parameters for the spectrogram
nperseg = 256  # Number of data points in each segment
noverlap = 128  # Number of overlapping points between segments

# Create the spectrogram
frequencies8, times8, Sxx8 = spectrogram(data8, fs=sampling_freq8, nperseg=256) #nperseg samples per segment, balance between high resolution and low resolution.
times8 -= 60*30

# Plot the spectrogram
plt.figure(figsize=(12, 6))
plt.pcolormesh(times8, frequencies8, 10 * np.log10(Sxx8), shading='gouraud', cmap="plasma", vmin=-170, vmax=-130)
plt.title('S1222a Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.colorbar(label='Intensity (dB)')
plt.axvline(2100)
plt.ylim(0.05, 1)  # Limit the y-axis to focus on lower frequencies
plt.xlim(0,1200)
plt.show()

stcopy8 = stream8.copy()
stcopy8.taper(0.05)
stcopy8.filter("bandpass", freqmin=0.1, freqmax=0.8, corners=4, zerophase=False)
stcopy8[0].plot();

trz8 = stcopy8.select(channel="BHN")[0]
origin_time = 60*30
time_for_trz8 = trz8.times() - origin_time

plt.figure(figsize=(6, 4))
plt.plot(time_for_trz8, trz8.data)
plt.xlim(0,1500)
plt.ylim(-6e-7,6e-7);
