# %%
import obspy
st = obspy.read(r"C:\Users\wille\InSight-seismic-data-downloader\DATA\BROADBAND\A\S1222a\S1222a_DISP.mseed")
print(st)
# Out:
# 3 Trace(s) in Stream:
# XB.ELYSE.02.BHZ | 2022-05-04T22:53:07.746000Z - 2022-05-05T00:53:07.646000Z | 20.0 Hz, 143999 samples
# XB.ELYSE.02.BHN | 2022-05-04T22:53:07.747000Z - 2022-05-05T00:53:07.647000Z | 20.0 Hz, 143999 samples
# XB.ELYSE.02.BHE | 2022-05-04T22:53:07.747000Z - 2022-05-05T00:53:07.647000Z | 20.0 Hz, 143999 samples

# %%
st.plot()

# %%
st.spectrogram()
# Out:
# [None, None, None]

# %%
st.spectrogram(log=True)
# Out:
# [None, None, None]

# %%
help(st.spectrogram)
# Out:
# Help on method spectrogram in module obspy.core.stream:
#
# spectrogram(**kwargs) method of obspy.core.stream.Stream instance
#     Create a spectrogram plot for each trace in the stream.
#
#     For details on kwargs that can be used to customize the spectrogram
#     plot see :func:`obspy.imaging.spectrogram.spectrogram`.
#
#     .. rubric:: Example
#
#     >>> from obspy import read
#     >>> st = read()
#     >>> st[0].spectrogram()  # doctest: +SKIP
#
#     .. plot::
#
#         from obspy import read
#         st = read()
#         st[0].spectrogram()

# %%
st.spectrogram(log=True, dbscale=True)
# Out:
# [None, None, None]

# %%
import obspy
st2 = obspy.read(r"C:\Users\wille\InSight-seismic-data-downloader\DATA\BROADBAND\A\S1222a\S1222a_ACC.mseed")
st2.plot()

# %%
st3 = obspy.read(r"C:\Users\wille\InSight-seismic-data-downloader\DATA\BROADBAND\A\S1222a\S1222a_VEL.mseed")
st3.plot()

# %%
st2.spectrogram(log=True, dbscale=True, mult=True)
st3.spectrogram(log=True, dbscale=True, mult=True)
# Out:
# [None, None, None]
