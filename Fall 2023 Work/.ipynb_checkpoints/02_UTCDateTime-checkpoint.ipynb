# %% [markdown]
# <div style='background-image: url("../share/images/header.svg") ; padding: 0px ; background-size: cover ; border-radius: 5px ; height: 250px'>
#     <div style="float: right ; margin: 50px ; padding: 20px ; background: rgba(255 , 255 , 255 , 0.7) ; width: 50% ; height: 150px">
#         <div style="position: relative ; top: 50% ; transform: translatey(-50%)">
#             <div style="font-size: xx-large ; font-weight: 900 ; color: rgba(0 , 0 , 0 , 0.8) ; line-height: 100%">ObsPy Tutorial</div>
#             <div style="font-size: large ; padding-top: 20px ; color: rgba(0 , 0 , 0 , 0.5)">Handling Time</div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Seismo-Live: http://seismo-live.org
#
# ##### Authors:
# * Lion Krischer ([@krischer](https://github.com/krischer))
# * Tobias Megies ([@megies](https://github.com/megies))
#
# ---

# %% [markdown]
# ![](images/obspy_logo_full_524x179px.png)

# %% [markdown]
# This is a bit dry but not very difficult and important to know. It is used everywhere in ObsPy!
#
#
# * All absolute time values are consistently handled with this class
# * Based on a double precision POSIX timestamp for accuracy
# * Timezone can be specified at initialization (if necessary)
# * In Coordinated Universal Time (UTC) so no need to deal with timezones, daylight savings, ...
#
# ---

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = 12, 8

# %% [markdown]
# ---
#
# ## Features of **`UTCDateTime`**
#
# #### Initialization

# %%
from obspy import UTCDateTime

print(UTCDateTime("2011-03-11T05:46:23.2"))        # mostly time strings defined by ISO standard
print(UTCDateTime("2011-03-11T14:46:23.2+09:00"))  # non-UTC timezone input
print(UTCDateTime(2011, 3, 11, 5, 46, 23, 2))
print(UTCDateTime(1299822383.2))
# Out:
# 2011-03-11T05:46:23.200000Z
# 2011-03-11T05:46:23.200000Z
# 2011-03-11T05:46:23.000002Z
# 2011-03-11T05:46:23.200000Z

# %%
# Current time can be initialized by leaving out any arguments
print(UTCDateTime())
# Out:
# 2023-12-01T04:41:11.365309Z

# %% [markdown]
# #### Attribute Access

# %%
time = UTCDateTime("2011-03-11T05:46:23.200000Z")
print(time.year)
print(time.julday)
print(time.timestamp)
print(time.weekday)
# try time.<Tab>
# Out:
# 2011
# 70
# 1299822383.2
# 4

# %% [markdown]
# #### Handling time differences
#
# * "**`+`**/**`-`**" defined to add seconds to an **`UTCDateTime`** object
# * "**`-`**" defined to get time difference of two **`UTCDateTime`** objects

# %%
time = UTCDateTime("2011-03-11T05:46:23.200000Z")
print(time)
# Out:
# 2011-03-11T05:46:23.200000Z

# %%
# one hour later
print(time + 3600)
# Out:
# 2011-03-11T06:46:23.200000Z

# %%
time2 = UTCDateTime(2012, 1, 1)
print(time2 - time)
# Out:
# 25553616.8

# %% [markdown]
# ### Exercises
#
# Calculate the number of days passed since the Tohoku main shock (the timestamp used above).

# %%
time3 = UTCDateTime(2023, 11, 30)
time4 = UTCDateTime(2023, 11, 30, 10)
print(time4)
# Out:
# 2023-11-30T10:00:00.000000Z

# %%
difference = time3 - time2
print(difference/(60*60*24))
# Out:
# 4351.0

# %% [markdown]
# Make a list of 10 UTCDateTime objects, starting today at 10:00 with a spacing of 90 minutes.

# %%
list_example = [UTCDateTime(2023, 11, 30, 10), UTCDateTime(2023, 11, 30, 11, 30), UTCDateTime(2023, 11, 30, 13), UTCDateTime(2023, 11, 30, 14, 30), UTCDateTime(2023, 11, 30, 16)]
print(list_example)
# Out:
# [UTCDateTime(2023, 11, 30, 10, 0), UTCDateTime(2023, 11, 30, 11, 30), UTCDateTime(2023, 11, 30, 13, 0), UTCDateTime(2023, 11, 30, 14, 30), UTCDateTime(2023, 11, 30, 16, 0)]

# %%
import obspy
from datetime import datetime, timedelta
from obspy import UTCDateTime
current_time = datetime.utcnow()
start_time = datetime(current_time.year, current_time.month, current_time.day, 10, 0)
utc_date_times = [UTCDateTime(start_time + timedelta(minutes=90 * i)) for i in range(10)]
for utc_dt in utc_date_times:
    print(utc_dt)
# Out:
# 2023-12-01T10:00:00.000000Z
# 2023-12-01T11:30:00.000000Z
# 2023-12-01T13:00:00.000000Z
# 2023-12-01T14:30:00.000000Z
# 2023-12-01T16:00:00.000000Z
# 2023-12-01T17:30:00.000000Z
# 2023-12-01T19:00:00.000000Z
# 2023-12-01T20:30:00.000000Z
# 2023-12-01T22:00:00.000000Z
# 2023-12-01T23:30:00.000000Z

# %% [markdown]
# Below is a list of strings with origin times of magnitude 8+ earthquakes since 2000 (fetched from IRIS). Assemble a list of interevent times in days. Use matplotlib to display a histogram.

# %%
times = ["2001-06-23T20:33:09",
         "2003-09-25T19:50:07",
         "2004-12-23T14:59:00",
         "2004-12-26T00:58:52",
         "2005-03-28T16:09:35",
         "2006-06-01T18:57:02",
         "2006-06-05T00:50:31",
         "2006-11-15T11:14:14",
         "2007-01-13T04:23:23",
         "2007-04-01T20:39:56",
         "2007-08-15T23:40:58",
         "2007-09-12T11:10:26",
         "2009-09-29T17:48:11",
         "2010-02-27T06:34:13",
         "2011-03-11T05:46:23",
         "2012-04-11T08:38:36",
         "2012-04-11T10:43:10",
         "2013-05-24T05:44:48"]

# %%
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib.dates import date2num
import numpy as np

datetime_objects = [datetime.strptime(time, "%Y-%m-%dT%H:%M:%S") for time in times]

interevent_times = np.diff(date2num(datetime_objects))  

plt.hist(interevent_times, bins=10, color='blue', edgecolor='black')
plt.xlabel('Interevent Time (days)')
plt.ylabel('Frequency')
plt.title('Histogram of Interevent Times for Magnitude 8+ Earthquakes Since 2000')
plt.show()
