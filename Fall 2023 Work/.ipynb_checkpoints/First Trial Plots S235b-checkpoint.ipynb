# %%
import obspy
st = obspy.read(r"C:\Users\wille\InSight-seismic-data-downloader\DATA\BROADBAND\A\S0235b\S0235b_DISP.mseed")
print(st)
st.plot()

#Just the default marsquake plotted using obspy plotting function
# Out:
# 3 Trace(s) in Stream:
# XB.ELYSE.02.BHZ | 2019-07-26T11:45:38.761000Z - 2019-07-26T13:45:38.761000Z | 20.0 Hz, 144001 samples
# XB.ELYSE.02.BHN | 2019-07-26T11:45:38.762000Z - 2019-07-26T13:45:38.762000Z | 20.0 Hz, 144001 samples
# XB.ELYSE.02.BHE | 2019-07-26T11:45:38.762000Z - 2019-07-26T13:45:38.762000Z | 20.0 Hz, 144001 samples

# %%
import matplotlib.pyplot as plt
trz = st.select(channel='BHZ')[0]
time = trz.times()
data = trz.data
plt.plot(time,data)
plt.show()

# %%
import obspy
cat = obspy.read_events(r"C:\Users\wille\InSight-seismic-data-downloader\events_extended_multiorigin_v14_2023-01-01.xml")
for event in cat:
    if event.event_descriptions[0].text == 'S0235b':
        print(event)
origin = s0235b.preferred_origin().time
scs_times = []
for pick in scs_times:
    scs_pick =
# Out:
# Event:	2019-07-26T12:15:38.748239Z | +10.177, +164.057 | 3.7  MW | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:insight.mqs/mqs2019onhx")
# 	             event_type: 'other event'
# 	   event_type_certainty: 'suspected'
# 	          creation_info: CreationInfo(agency_id='mqs', author='scevent@sc3mars-op', creation_time=UTCDateTime(2019, 7, 27, 15, 40, 59, 920471))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:insight.mqs/Origin/20220922141652.922528.73698")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:insight.mqs/Magnitude/20230331-123141/ba3ee975")
# 	                   ---------
# 	     event_descriptions: 2 Elements
# 	                  picks: 39 Elements
# 	       focal_mechanisms: 3 Elements
# 	                origins: 6 Elements
# 	             magnitudes: 11 Elements

# %%
#Work to do over break
#Notebook 9,
